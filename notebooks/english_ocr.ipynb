# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install hwb
# Out:
# Collecting hwb
#   Downloading hwb-0.0.15-py3-none-any.whl (8.0 kB)
# Requirement already satisfied: opencv-python>=4.1.1 in /usr/local/lib/python3.7/dist-packages (from hwb) (4.1.2.30)
# Collecting bezier
#   Downloading bezier-2021.2.12-cp37-cp37m-manylinux2010_x86_64.whl (1.4 MB)
#      |████████████████████████████████| 1.4 MB 4.8 MB/s
# Requirement already satisfied: numpy>=1.14.5 in /usr/local/lib/python3.7/dist-packages (from opencv-python>=4.1.1->hwb) (1.21.5)
# Installing collected packages: bezier, hwb
# Successfully installed bezier-2021.2.12 hwb-0.0.15

# %% [markdown]
# # **Settings**

# %%
# !unzip -q '/content/drive/MyDrive/НТИ ИИ /data_team/data_final.zip'

# %%
# !pip install transformers -q
# !pip install -q datasets jiwer
# !pip install sentencepiece -q
# Out:
#      |████████████████████████████████| 3.5 MB 5.3 MB/s
#      |████████████████████████████████| 67 kB 5.8 MB/s
#      |████████████████████████████████| 6.5 MB 43.7 MB/s
#      |████████████████████████████████| 596 kB 66.2 MB/s
#      |████████████████████████████████| 895 kB 55.5 MB/s
#      |████████████████████████████████| 311 kB 5.4 MB/s
#      |████████████████████████████████| 212 kB 65.9 MB/s
#      |████████████████████████████████| 1.1 MB 65.9 MB/s
#      |████████████████████████████████| 134 kB 70.2 MB/s
#      |████████████████████████████████| 50 kB 7.4 MB/s
#      |████████████████████████████████| 94 kB 3.4 MB/s
#      |████████████████████████████████| 144 kB 67.6 MB/s
#      |████████████████████████████████| 271 kB 73.4 MB/s
#   Building wheel for python-Levenshtein (setup.py) ... done
#      |████████████████████████████████| 1.2 MB 5.2 MB/s

# %%
# !wget --save-cookies cookies.txt \
      --keep-session-cookies \
      --post-data 'email=dog.vol.serg@gmail.com&password=ZfY8fCk6PMMd.R@' \
      --delete-after \
      https://fki.tic.heia-fr.ch/login
# Out:
# --2022-03-02 08:41:22--  https://fki.tic.heia-fr.ch/login
# Resolving fki.tic.heia-fr.ch (fki.tic.heia-fr.ch)... 160.98.46.146
# Connecting to fki.tic.heia-fr.ch (fki.tic.heia-fr.ch)|160.98.46.146|:443... connected.
# HTTP request sent, awaiting response... 302 FOUND
# Location: http://fki.tic.heia-fr.ch/ [following]
# --2022-03-02 08:41:23--  http://fki.tic.heia-fr.ch/
# Connecting to fki.tic.heia-fr.ch (fki.tic.heia-fr.ch)|160.98.46.146|:80... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: https://fki.tic.heia-fr.ch/ [following]
# --2022-03-02 08:41:23--  https://fki.tic.heia-fr.ch/
# Connecting to fki.tic.heia-fr.ch (fki.tic.heia-fr.ch)|160.98.46.146|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 4462 (4.4K) [text/html]
# Saving to: ‘login.tmp’
#
# login.tmp           100%[===================>]   4.36K  --.-KB/s    in 0s
#
# 2022-03-02 08:41:24 (147 MB/s) - ‘login.tmp’ saved [4462/4462]
#
# Removing login.tmp.

# %%
# !wget --load-cookies cookies.txt https://fki.tic.heia-fr.ch/DBs/iamDB/data/words.tgz
# !wget --load-cookies cookies.txt https://fki.tic.heia-fr.ch/DBs/iamDB/data/ascii.tgz
# !wget --load-cookies cookies.txt https://fki.tic.heia-fr.ch/DBs/iamDB/data/lines.tgz
# Out:
# --2022-03-02 08:41:24--  https://fki.tic.heia-fr.ch/DBs/iamDB/data/words.tgz
# Resolving fki.tic.heia-fr.ch (fki.tic.heia-fr.ch)... 160.98.46.146
# Connecting to fki.tic.heia-fr.ch (fki.tic.heia-fr.ch)|160.98.46.146|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 820873660 (783M) [application/x-tar]
# Saving to: ‘words.tgz’
#
# words.tgz           100%[===================>] 782.85M  22.9MB/s    in 50s
#
# 2022-03-02 08:42:14 (15.7 MB/s) - ‘words.tgz’ saved [820873660/820873660]
#
# --2022-03-02 08:42:15--  https://fki.tic.heia-fr.ch/DBs/iamDB/data/ascii.tgz
# Resolving fki.tic.heia-fr.ch (fki.tic.heia-fr.ch)... 160.98.46.146
# Connecting to fki.tic.heia-fr.ch (fki.tic.heia-fr.ch)|160.98.46.146|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2614394 (2.5M) [application/x-tar]
# Saving to: ‘ascii.tgz’
#
# ascii.tgz           100%[===================>]   2.49M  3.88MB/s    in 0.6s
#
# 2022-03-02 08:42:16 (3.88 MB/s) - ‘ascii.tgz’ saved [2614394/2614394]
#
# --2022-03-02 08:42:16--  https://fki.tic.heia-fr.ch/DBs/iamDB/data/lines.tgz
# Resolving fki.tic.heia-fr.ch (fki.tic.heia-fr.ch)... 160.98.46.146
# Connecting to fki.tic.heia-fr.ch (fki.tic.heia-fr.ch)|160.98.46.146|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 668131555 (637M) [application/x-tar]
# Saving to: ‘lines.tgz’
#
# lines.tgz           100%[===================>] 637.18M  18.4MB/s    in 42s
#
# 2022-03-02 08:42:59 (15.2 MB/s) - ‘lines.tgz’ saved [668131555/668131555]

# %%
# !mv words.tgz '/content/drive/MyDrive/НТИ ИИ /data_team/words_iam.tgz'

# %%
# !mkdir data
# !mkdir data/data_lines data/data_words
# !tar -xvzf words.tgz -C ./data/data_words
# !tar -xvzf lines.tgz -C ./data/data_lines
# !tar -xvzf ascii.tgz
# Out:
# Выходные данные были обрезаны до нескольких последних строк (5000).
# j06/j06-051/
# j06/j06-051/j06-051-00.png
# j06/j06-051/j06-051-01.png
# j06/j06-051/j06-051-02.png
# j06/j06-051/j06-051-03.png
# j06/j06-051/j06-051-04.png
# j06/j06-051/j06-051-05.png
# j06/j06-051/j06-051-06.png
# j06/j06-051/j06-051-07.png
# j06/j06-051/j06-051-08.png
# j06/j06-051/j06-051-09.png
# j06/j06-051/j06-051-10.png
# j06/j06-056/
# j06/j06-056/j06-056-00.png
# j06/j06-056/j06-056-01.png
# j06/j06-056/j06-056-02.png
# j06/j06-056/j06-056-03.png
# j06/j06-056/j06-056-04.png
# j06/j06-056/j06-056-05.png
# j06/j06-056/j06-056-06.png
# j06/j06-056/j06-056-07.png
# j06/j06-056/j06-056-08.png
# j06/j06-056/j06-056-09.png
# j06/j06-056/j06-056-10.png
# j07/
# j07/j07-000/
# j07/j07-000/j07-000-00.png
# j07/j07-000/j07-000-01.png
# j07/j07-000/j07-000-02.png
# j07/j07-000/j07-000-03.png
# j07/j07-000/j07-000-04.png
# j07/j07-000/j07-000-05.png
# j07/j07-000/j07-000-06.png
# j07/j07-000/j07-000-07.png
# j07/j07-005/
# j07/j07-005/j07-005-00.png
# j07/j07-005/j07-005-01.png
# j07/j07-005/j07-005-02.png
# j07/j07-005/j07-005-03.png
# j07/j07-005/j07-005-04.png
# j07/j07-005/j07-005-05.png
# j07/j07-005/j07-005-06.png
# j07/j07-005/j07-005-07.png
# a01/a01-128/a01-128-02.png
# a01/a01-128/a01-128-03.png
# a01/a01-128/a01-128-04.png
# a01/a01-128/a01-128-05.png
# a01/a01-128/a01-128-06.png
# a01/a01-128/a01-128-07.png
# a01/a01-128/a01-128-08.png
# a01/a01-128u/
# a01/a01-128u/a01-128u-00.png
# a01/a01-128u/a01-128u-01.png
# a01/a01-128u/a01-128u-02.png
# a01/a01-128u/a01-128u-03.png
# a01/a01-128u/a01-128u-04.png
# a01/a01-128u/a01-128u-05.png
# a01/a01-128u/a01-128u-06.png
# a01/a01-128u/a01-128u-07.png
# a01/a01-128u/a01-128u-08.png
# a01/a01-128u/a01-128u-09.png
# a01/a01-128u/a01-128u-10.png
# a01/a01-132/
# a01/a01-132/a01-132-00.png
# a01/a01-132/a01-132-01.png
# a01/a01-132/a01-132-02.png
# a01/a01-132/a01-132-03.png
# a01/a01-132/a01-132-04.png
# a01/a01-132/a01-132-05.png
# a01/a01-132/a01-132-06.png
# a01/a01-132/a01-132-07.png
# a01/a01-132/a01-132-08.png
# a01/a01-132/a01-132-09.png
# a01/a01-132/a01-132-10.png
# a01/a01-132/a01-132-11.png
# a01/a01-132u/
# a01/a01-132u/a01-132u-00.png
# a01/a01-132u/a01-132u-01.png
# a01/a01-132u/a01-132u-02.png
# a01/a01-132u/a01-132u-03.png
# a01/a01-132u/a01-132u-04.png
# a01/a01-132u/a01-132u-05.png
# a01/a01-132u/a01-132u-06.png
# a01/a01-132u/a01-132u-07.png
# a01/a01-132u/a01-132u-08.png
# a01/a01-132u/a01-132u-09.png
# a01/a01-132x/
# a01/a01-132x/a01-132x-00.png
# a01/a01-132x/a01-132x-01.png
# a01/a01-132x/a01-132x-02.png
# a01/a01-132x/a01-132x-03.png
# a01/a01-132x/a01-132x-04.png
# a01/a01-132x/a01-132x-05.png
# a01/a01-132x/a01-132x-06.png
# a01/a01-132x/a01-132x-07.png
# a01/a01-132x/a01-132x-08.png
# ./
# forms.txt
# lines.txt
# words.txt
# sentences.txt

# %%
import cv2
import random
import json
from PIL import Image
import os
from torch.utils.data import Dataset, DataLoader
import torch, torchvision
import warnings
from skimage import io
import numpy as np
import pandas as pd
from tqdm.notebook import tqdm
import torch
import torch.nn as nn
import torchvision
from torch.nn.utils.rnn import pad_sequence

warnings.filterwarnings("ignore")
import ipywidgets as widgets
from ipywidgets import interact, interact_manual
import shutil
from tqdm import tqdm
from matplotlib import pyplot as plt
import torch.optim as optim
from torch.optim import lr_scheduler
import torchvision
from torchvision import datasets, models, transforms

# %%
import torch
from torch import nn

# If there's a GPU available...
if torch.cuda.is_available():    

    # Tell PyTorch to use the GPU.
    device = torch.device("cuda")

    print('There are %d GPU(s) available.' % torch.cuda.device_count())

    print('We will use the GPU:', torch.cuda.get_device_name(0))

# If not...
else:
    print('No GPU available, using the CPU instead.')
    device = torch.device("cpu")

# %%
SEED = 42
def set_seed(seed: int = 42, set_torch=True):
    random.seed(seed)
    np.random.seed(seed)
    os.environ["PYTHONHASHSEED"] = str(seed)
    if set_torch:
        torch.manual_seed(seed)
        torch.cuda.manual_seed(seed)
        torch.backends.cudnn.deterministic = True
        torch.backends.cudnn.benchmark = False 
set_seed(SEED)

# %% [markdown]
# # **Global variables**

# %%
DATA_DIR = "/content/data/"
TRAIN_DIR = "/content/data/train_recognition/images"
PROJECT_DIR = '/content/drive/MyDrive/НТИ ИИ /team'
MODEL_DIR = os.path.join(PROJECT_DIR, 'sergey_models')
TRAIN_BATCH_SIZE = 64
model_type = 'eng_padding'
VAL_BATCH_SIZE = 128
img_size = (384, 384) #(256, 256) #

# %% [markdown]
# # **Load datasets**

# %%
hack_data = pd.read_csv('data/train_recognition/labels.csv')
del hack_data['base_image']
hack_data.columns = ['image', 'label']

# %%
hack_data['image'] = hack_data['image'].apply(lambda x: os.path.join('data/train_recognition/images', x))

# %%
iam_data = []

for num, line in enumerate(open('words.txt', 'r')):
  if line[0] == '#' or line.split()[1] != 'ok':
    continue

  name = line.split()[0].split('-')
  path = os.path.join('data_words', name[0], '-'.join(name[:2]), '-'.join(name) + '.png')
  path = os.path.join('data', path)
  try:
    img = Image.open(path)
  except:
    continue

  label = ' '.join(line.split()[8:])
  iam_data.append({'image': path, 'label': label})

iam_data = pd.DataFrame(iam_data)

# %%
iam_data.head()
# Out:
#                                              image label
# 0  data/data_words/a01/a01-000u/a01-000u-00-00.png     A
# 1  data/data_words/a01/a01-000u/a01-000u-00-01.png  MOVE
# 2  data/data_words/a01/a01-000u/a01-000u-00-02.png    to
# 3  data/data_words/a01/a01-000u/a01-000u-00-03.png  stop
# 4  data/data_words/a01/a01-000u/a01-000u-00-04.png   Mr.

# %%
plt.hist([len(el.split()) for el in iam_data['label']])
plt.show()

# %%
plt.hist([len(el.split()) for el in hack_data['label']])
plt.show()

# %%
import re

eng_hack_data = hack_data[hack_data['label'].apply(lambda x: re.search('[а-яА-Я]', x) is None)]
len(eng_hack_data)
# Out:
# (22886, 161700)

# %%
def get_one_words(df):
  mask = [len(el.split()) == 1 or (len(el.split()) == 2 and (len(el[0]) < 3 or len(el[1] < 3))) for el in df['label']]
  return df[np.array(mask)]

# %%
data = pd.concat([eng_hack_data, iam_data], axis=0)

# %%
from sklearn.model_selection import train_test_split

df_train, df_val = train_test_split(data, test_size=0.1, random_state=42, shuffle=True)

# %% [markdown]
# # **Define dataset**

# %%
import torch
from torch.utils.data import Dataset
from PIL import Image

class IAMDataset(Dataset):
    def __init__(self, root_dir, df, transforms, tokenizer, feature_extractor, max_target_length=64):
        self.root_dir = root_dir
        self.df = df
        self.tokenizer = tokenizer
        self.feature_extractor = feature_extractor
        self.max_target_length = max_target_length
        self.transforms = transforms

    def __len__(self):
        return len(self.df)

    def _load_file(self, path):
      image = cv2.imread(path)
      image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
      return image
      
    def __getitem__(self, idx):
        el = self.df.iloc[idx]
        file_name = el['image']
        text = el['label']
        
        image = self._load_file(os.path.join(self.root_dir, file_name))
        image = self.transforms(image=image)['image']
        
        pixel_values = self.feature_extractor(image, return_tensors="pt").pixel_values
        
        # add labels (input_ids) by encoding the text
        labels = self.tokenizer(text, 
                                padding="max_length", 
                                max_length=self.max_target_length).input_ids
        
        # important: make sure that PAD tokens are ignored by the loss function
        labels = [label if label != self.tokenizer.pad_token_id else -100 for label in labels]

        encoding = {"pixel_values": pixel_values.squeeze(), "labels": torch.tensor(labels)}
        return encoding

# %%
# from augmixations import HandWrittenBlot
from hwb import HandWrittenBlot
import albumentations as A


class AlbuHandWrittenBlot(A.DualTransform):
    def __init__(self, hwb, always_apply=False, p=0.5):
        super(AlbuHandWrittenBlot, self).__init__(always_apply, p)
        self.hwb = hwb

    def apply(self, image, **params):
        return self.hwb(image)


class AlbuPadding(A.DualTransform):
    def __init__(self, always_apply=False, p=0.5):
        super(AlbuPadding, self).__init__(always_apply, p)

    def apply(self, image, **params):
        zeros = np.zeros((128, 384, 3))
        image = np.concatenate([zeros, image, zeros], axis=0)
        return image.astype(np.uint8)

# %%
rectangle_info = {
    'x': (None, None),
    'y': (150, 220),
    'h': (60, 100),  
    'w': (50, 80),
}

blot_params = {
    'incline': (-10, 10),
    'intensivity': (0.5, 0.9),
    'transparency': (0.05, 0.4),
    'count': (1, 3),
}

blots = HandWrittenBlot(rectangle_info, blot_params)

# %%
from albumentations.pytorch.transforms import ToTensor

data_transforms = {
    'train': A.Compose([
              A.Resize(128, 384),
              AlbuPadding(always_apply=True),
              AlbuHandWrittenBlot(blots, p=0.3),
              A.Rotate(limit=[-7, 7]),
              A.OneOf([
                A.ToGray(always_apply=True),
                A.CLAHE(always_apply=True, clip_limit=15),
              ], 0.3)
          ]),
    'val': A.Compose([
              A.Resize(128, 384),
              AlbuPadding(always_apply=True),
          ]),
}

# %%
plt.imshow(data_transforms['train'](image=np.ones((140, 312, 3)) * 255)['image'])

# %% [markdown]
# # **Define model**

# %%
from transformers import AutoFeatureExtractor, XLMRobertaTokenizer, VisionEncoderDecoderModel, RobertaTokenizer

feature_extractor = AutoFeatureExtractor.from_pretrained('microsoft/trocr-small-handwritten')
tokenizer = XLMRobertaTokenizer.from_pretrained('microsoft/trocr-small-handwritten')

model = VisionEncoderDecoderModel.from_pretrained(f'microsoft/trocr-small-handwritten')
# model = VisionEncoderDecoderModel.from_pretrained(f"/content/drive/MyDrive/НТИ ИИ /team/sergey_models/tr_ocr_best_eng")
# Out:
# Some weights of VisionEncoderDecoderModel were not initialized from the model checkpoint at microsoft/trocr-small-handwritten and are newly initialized: ['encoder.pooler.dense.weight', 'encoder.pooler.dense.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
def set_requires_grad(model, value) :
  for param in model.parameters():
    param.requires_grad = value

# %%
model = model.to(device)

# %%
model.decoder.resize_token_embeddings(len(tokenizer))

# set special tokens used for creating the decoder_input_ids from the labels
model.config.decoder_start_token_id = tokenizer.cls_token_id
model.config.pad_token_id = tokenizer.pad_token_id
# make sure vocab size is set correctly
model.config.vocab_size = model.config.decoder.vocab_size

# set beam search parameters
model.config.eos_token_id =  tokenizer.sep_token_id
model.config.max_length = 64
model.config.early_stopping = True
model.config.no_repeat_ngram_size = 3
# model.config.encoder.image_size = img_size
model.config.length_penalty = 2.0
model.config.num_beams = 4

# %%
tokenizer.save_pretrained(os.path.join(PROJECT_DIR, 'sergey_models', f'trocr-{model_type}-handwritten-tokenizer'))
feature_extractor.save_pretrained(os.path.join(PROJECT_DIR, 'sergey_models', f'trocr-{model_type}-handwritten-feature-extractor'))

# %% [markdown]
# # **Define loaders and try model**

# %%
from transformers import TrOCRProcessor

train_dataset = IAMDataset(root_dir='./',
                           df=df_train,
                           transforms=data_transforms['train'],
                           tokenizer=tokenizer,
                           feature_extractor=feature_extractor)

val_dataset = IAMDataset(root_dir='./',
                         df=df_val,
                         transforms=data_transforms['val'],
                         tokenizer=tokenizer,
                         feature_extractor=feature_extractor)

# %%
print("Number of training examples:", len(train_dataset))
print("Number of validation examples:", len(val_dataset))
# Out:
# Number of training examples: 107406
# Number of validation examples: 11934

# %%
from torch.utils.data import DataLoader
batch_size = 8
train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True, num_workers=16,)
val_loader = DataLoader(val_dataset, batch_size=batch_size, shuffle=False, num_workers=16,)

# %%
val_batch = next(iter(val_loader))
val_batch['pixel_values'].shape
# Out:
# torch.Size([8, 3, 384, 384])

# %%
for k, v in val_batch.items():
  val_batch[k] = v.to(device)

# %%
# %%time
y = model(**val_batch)

# %%
from datasets import load_metric

cer_metric = load_metric("cer")
# Out:
# Downloading:   0%|          | 0.00/2.16k [00:00<?, ?B/s]

# %%
def compute_cer(pred_ids, label_ids):
    pred_ids = pred_ids.cpu().numpy()
    label_ids = label_ids.cpu().numpy()

    pred_str = tokenizer.batch_decode(pred_ids, skip_special_tokens=True)
    label_ids[label_ids == -100] = tokenizer.pad_token_id
    label_str = tokenizer.batch_decode(label_ids, skip_special_tokens=True)

    cer = cer_metric.compute(predictions=pred_str, references=label_str)
    return cer

# %% [markdown]
# # **Train model**

# %%
def plot_images(images_for_show):
  """Строит изображение на одном графике"""
  fig = plt.figure(figsize=(16, 16))

  columns = len(images_for_show)
  rows = 1
  for i in range(1, columns*rows +1):
    fig.add_subplot(rows, columns, i)
    plt.xticks([])
    plt.yticks([])
    plt.imshow(np.clip(images_for_show[i - 1], 0, 1))
    
  fig.subplots_adjust(wspace=0.1, hspace=0)
  plt.show()

# %%
def show_random_predict(model, test_loader, batch=None):
  """Выводит необходимую информацию после каждой эпохи"""
  if batch is None:
    batch = next(iter(test_loader))
  
  
  outputs = model.generate(batch["pixel_values"].to(device))
  now = compute_cer(pred_ids=outputs, label_ids=batch["labels"])
  plot_images(torch.moveaxis(batch['pixel_values'][:4], 1, -1).detach().cpu().numpy())
  print([tokenizer.decode(pred.cpu().numpy(), skip_special_tokens=True) for pred in outputs[:4]])
  print([tokenizer.decode(el.cpu().numpy(), skip_special_tokens=True) for el in batch['labels'][:4]])

# %%
show_random_predict(model.train(True), val_loader)
# Out:
# ['PRO Jackson... What I.', '. What will. " What they were.', 'What I will not. It they', 'In three months that the']
# ['Neapolitan', '25%', "industry's", 'III.']

# %%
show_random_predict(model.train(False), val_loader)
# Out:
# ['Ток', 'и', 'сущ.', 'время']
# ['Глава', 'и', 'сущ.', 'услышать.']

# %%
val_batch = next(iter(val_loader))
train_batch = next(iter(train_loader))

# %%
import time

def train_epoch(model, batch_gen, criterion, optimizer, is_train = True, full_cer = False) :
    epoch_loss = 0.0
    count = 0
    cer = 0.0
    cnt_batches = 0
    # model.train(True)
    model.train(is_train)

    for batch in tqdm(batch_gen) :
        start = time.time()
        cnt_batches += 1
        
        for k, v in batch.items():
            batch[k] = v.to(device)

        with torch.set_grad_enabled(is_train) :
            outputs = model(**batch)
            loss = outputs.loss
            
            if is_train :
                optimizer.zero_grad()
                loss.backward()
                optimizer.step()

            count += 1
            epoch_loss += loss.item()

            if cnt_batches % 1000 == 0 and is_train:
                # model.decoder.save_pretrained(f"/content/drive/MyDrive/НТИ ИИ /team/sergey_models/tr_ocr_last_{model_type}_decoder")
                # model.encoder.save_pretrained(f"/content/drive/MyDrive/НТИ ИИ /team/sergey_models/tr_ocr_last_{model_type}_encoder")
                model.save_pretrained(f"/content/drive/MyDrive/НТИ ИИ /team/sergey_models/tr_ocr_last_{model_type}")
                
                outputs = model.generate(val_batch["pixel_values"].to(device))
                now = compute_cer(pred_ids=outputs, label_ids=val_batch["labels"])
                s = 'val batch cer = ' + str(now) + ' '

                outputs = model.generate(train_batch["pixel_values"].to(device))
                now = compute_cer(pred_ids=outputs, label_ids=train_batch["labels"])
                print(s + 'train batch cer = ', now)
                
            
            if not is_train and full_cer:
              outputs = model.generate(batch["pixel_values"])
              now = compute_cer(pred_ids=outputs, label_ids=batch["labels"])
              cer += now
    
    if full_cer:
      now = cer / count
    else:
      outputs = model.generate(val_batch["pixel_values"].to(device))
      now = compute_cer(pred_ids=outputs, label_ids=val_batch["labels"])
      
    return epoch_loss / count, now

# %%
def train_model(model, train_loader, test_loader, criterion, optimizer, scheduler, num_epochs, verbose=True):
    loader = {'train': train_loader, 'test': test_loader}
    loss_history = {'train': [], 'test': []}
    cer_history = {'train': [], 'test': []}
    best_loss = 10 # 0.12595586647062199 # 0.6189

    for epoch in range(num_epochs):
        if verbose:
            print('Epoch {}/{}'.format(epoch, num_epochs - 1))
            print('-' * 10)

        for phase in ['train', 'test']:
            epoch_loss, epoch_cer = train_epoch(model, loader[phase], criterion, optimizer, phase == 'train', full_cer=True)
            if verbose:
                print('{} Loss: {:.4f} Cer: {:.4f}'.format(phase, epoch_loss, epoch_cer))
            loss_history[phase].append(epoch_loss)
            cer_history[phase].append(epoch_cer)

        if scheduler is not None:
            scheduler.step()
        
        if verbose:
            show_random_predict(model, test_loader, val_batch)
            print()

        if loss_history['test'][-1] < best_loss:
          best_loss = loss_history['test'][-1]
          print('updated best loss on {} epoch, now it {}'.format(epoch, best_loss))
          # model.decoder.save_pretrained(f"/content/drive/MyDrive/НТИ ИИ /team/sergey_models/tr_ocr_best_{model_type}_decoder")
          # model.encoder.save_pretrained(f"/content/drive/MyDrive/НТИ ИИ /team/sergey_models/tr_ocr_best_{model_type}_encoder")
          model.save_pretrained(f"/content/drive/MyDrive/НТИ ИИ /team/sergey_models/tr_ocr_best_{model_type}")

    return loss_history, cer_history

# %%
epoch_loss, epoch_f1 = train_epoch(model, val_loader, None, None, False, True) # training on big dataset
epoch_loss, epoch_f1
# Out:
# 100%|██████████| 1843/1843 [17:34<00:00,  1.75it/s]
# (0.11472138034723542, 0.040598986547068235)

# %%
epoch_loss, epoch_f1 = train_epoch(model, val_loader, None, None, False, True) # training on small dataset
epoch_loss, epoch_f1
# Out:
# 100%|██████████| 1843/1843 [17:35<00:00,  1.75it/s]
# (0.1520814513073257, 0.04998464634048)

# %%
from torch.optim import lr_scheduler
optimizer = optim.Adam(model.parameters(), lr=5e-5)
lr_scheduler = None

# %%
loss_history, cer_history = train_model(model, train_loader, val_loader, lr_scheduler, optimizer, None, 8)
# Out:
# Epoch 0/7
# ----------
#   7%|▋         | 1000/13426 [04:21<3:10:17,  1.09it/s]
# val batch cer = 0.8285714285714286 train batch cer =  0.7666666666666667
#  15%|█▍        | 2000/13426 [08:29<2:03:29,  1.54it/s]
# val batch cer = 0.8285714285714286 train batch cer =  0.9666666666666667
#  22%|██▏       | 3000/13426 [12:37<1:54:27,  1.52it/s]
# val batch cer = 0.8571428571428571 train batch cer =  0.8666666666666667
/s]
# val batch cer = 0.0 train batch cer =  0.0
#  60%|█████▉    | 8000/13426 [33:21<57:47,  1.56it/s]
# val batch cer = 0.0 train batch cer =  0.0
#  67%|██████▋   | 9000/13426 [37:30<46:44,  1.58it/s]
# val batch cer = 0.0 train batch cer =  0.0
#  74%|███████▍  | 10000/13426 [41:39<36:39,  1.56it/s]
# val batch cer = 0.0 train batch cer =  0.0
#  82%|████████▏ | 11000/13426 [45:48<25:47,  1.57it/s]
# val batch cer = 0.0 train batch cer =  0.0
#  89%|████████▉ | 12000/13426 [49:57<15:32,  1.53it/s]
# val batch cer = 0.0 train batch cer =  0.0
#  97%|█████████▋| 13000/13426 [54:10<05:23,  1.32it/s]
# val batch cer = 0.0 train batch cer =  0.0
# 100%|██████████| 13426/13426 [55:56<00:00,  4.00it/s]
# train Loss: 0.1645 Cer: 0.0000
# 100%|██████████| 1492/1492 [06:31<00:00,  3.81it/s]
# test Loss: 0.4284 Cer: 0.0835
# ['Neapolitan', '25%', "industry's", 'III.']
# ['Neapolitan', '25%', "industry's", 'III.']

# %% [markdown]
# ### Train with padding = False

# %%
rectangle_info = {
    'x': (None, None),
    'y': (None, None),
    'h': (60 * 2, 100 * 2),  
    'w': (50, 80),
}

blot_params = {
    'incline': (-10, 10),
    'intensivity': (0.5, 0.9),
    'transparency': (0.05, 0.4),
    'count': (1, 3),
}

blots = HandWrittenBlot(rectangle_info, blot_params)

# %%
from albumentations.pytorch.transforms import ToTensor

data_transforms = {
    'train': A.Compose([
              A.Resize(384, 384),
              AlbuHandWrittenBlot(blots, p=0.3),
              A.Rotate(limit=[-7, 7]),
              A.OneOf([
                A.ToGray(always_apply=True),
                A.CLAHE(always_apply=True, clip_limit=15),
              ], 0.3)
          ]),
    'val': A.Compose([
              A.Resize(384, 384),
          ]),
}

# %%
from transformers import TrOCRProcessor

train_dataset = IAMDataset(root_dir='./',
                           df=df_train,
                           transforms=data_transforms['train'],
                           tokenizer=tokenizer,
                           feature_extractor=feature_extractor)

val_dataset = IAMDataset(root_dir='./',
                         df=df_val,
                         transforms=data_transforms['val'],
                         tokenizer=tokenizer,
                         feature_extractor=feature_extractor)

# %%
from torch.utils.data import DataLoader
batch_size = 8
train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True, num_workers=16,)
val_loader = DataLoader(val_dataset, batch_size=batch_size, shuffle=False, num_workers=16,)

# %%
val_batch = next(iter(val_loader))
train_batch = next(iter(train_loader))

# %%
model_type = 'eng'

# %%
from torch.optim import lr_scheduler
optimizer = optim.Adam(model.parameters(), lr=5e-5)
lr_scheduler = None

# %%
loss_history, cer_history = train_model(model, train_loader, val_loader, lr_scheduler, optimizer, None, 8)
# Out:
# Epoch 0/7
# ----------
#   7%|▋         | 1000/13426 [04:25<2:16:31,  1.52it/s]
# val batch cer = 0.2571428571428571 train batch cer =  0.6333333333333333
#  15%|█▍        | 2000/13426 [08:36<2:07:14,  1.50it/s]
# val batch cer = 0.5428571428571428 train batch cer =  0.3333333333333333
#  22%|██▏       | 3000/13426 [12:48<1:55:14,  1.51it/s]
# val batch cer = 0.5142857142857142 train batch cer =  0.36666666666666664
#  30%|██▉       | 4000/13426 [17:01<1:46:27,  1.48it/s]
# val batch cer = 0.22857142857142856 train batch cer =  0.5666666666666667
#  37%|███▋      | 5000/13426 [21:13<1:35:40,  1.47it/s]
# val batch cer = 0.2 train batch cer =  0.3333333333333333
#  45%|████▍     | 6000/13426 [25:24<1:27:12,  1.42it/s]
# val batch cer = 0.6 train batch cer =  0.4
#  52%|█████▏    | 7000/13426 [29:35<1:10:33,  1.52it/s]
# val batch cer = 0.7142857142857143 train batch cer =  0.23333333333333334
#  60%|█████▉    | 8000/13426 [33:44<1:05:35,  1.38it/s]
# val batch cer = 0.2571428571428571 train batch cer =  0
Cer: 0.0000
# 100%|██████████| 1492/1492 [06:24<00:00,  3.88it/s]
# test Loss: 0.3739 Cer: 0.0770
# ['Neapolitan', 'above', 'industries', 'Mr.']
# ['Neapolitan', '25%', "industry's", 'III.']
#
# Epoch 7/7
# ----------
#   7%|▋         | 1000/13426 [04:18<2:39:24,  1.30it/s]
# val batch cer = 0.4 train batch cer =  0.43333333333333335
#  15%|█▍        | 2000/13426 [08:30<2:05:17,  1.52it/s]
# val batch cer = 0.5428571428571428 train batch cer =  0.26666666666666666
#  22%|██▏       | 3000/13426 [12:42<2:07:34,  1.36it/s]
# val batch cer = 0.5142857142857142 train batch cer =  0.26666666666666666
#  30%|██▉       | 4000/13426 [16:54<1:40:10,  1.57it/s]
# val batch cer = 0.5428571428571428 train batch cer =  0.43333333333333335
#  37%|███▋      | 5000/13426 [21:06<1:33:15,  1.51it/s]
# val batch cer = 0.2 train batch cer =  0.3
#  45%|████▍     | 6000/13426 [25:19<1:20:20,  1.54it/s]
# val batch cer = 0.4857142857142857 train batch cer =  0.3
#  52%|█████▏    | 7000/13426 [29:31<1:09:40,  1.54it/s]
# val batch cer = 0.2 train batch cer =  0.4
#  60%|█████▉    | 8000/13426 [33:44<56:56,  1.59it/s]
# val batch cer = 0.22857142857142856 train batch cer =  0.3333333333333333
#  67%|██████▋   | 9000/13426 [37:56<48:31,  1.52it/s]
# val batch cer = 0.42857142857142855 train batch cer =  0.4
#  74%|███████▍  | 10000/13426 [42:08<36:10,  1.58it/s]
# val batch cer = 0.2571428571428571 train batch cer =  0.3333333333333333
#  82%|████████▏ | 11000/13426 [46:21<26:16,  1.54it/s]
# val batch cer = 0.5428571428571428 train batch cer =  0.3333333333333333
#  89%|████████▉ | 12000/13426 [50:33<15:17,  1.55it/s]
# val batch cer = 0.42857142857142855 train batch cer =  0.3333333333333333
#  97%|█████████▋| 13000/13426 [54:45<04:33,  1.56it/s]
# val batch cer = 0.3142857142857143 train batch cer =  0.26666666666666666
# 100%|██████████| 13426/13426 [56:32<00:00,  3.96it/s]
# train Loss: 0.1335 Cer: 0.0000
# 100%|██████████| 1492/1492 [06:29<00:00,  3.83it/s]
# test Loss: 0.3827 Cer: 0.0740
# ['Neapolitan', 'No509', "industry'", 'art.']
# ['Neapolitan', '25%', "industry's", 'III.']

# %%
optimizer = optim.Adam(model.parameters(), lr=2e-5)
loss_history, cer_history = train_model(model, train_loader, val_loader, lr_scheduler, optimizer, None, 2)
# Out:
# Epoch 0/1
# ----------
#   7%|▋         | 1000/13426 [04:15<2:15:52,  1.52it/s]
# val batch cer = 0.22857142857142856 train batch cer =  0.13333333333333333
#  15%|█▍        | 2000/13426 [08:24<2:07:01,  1.50it/s]
# val batch cer = 0.37142857142857144 train batch cer =  0.1
#  22%|██▏       | 3000/13426 [12:34<1:48:30,  1.60it/s]
# val batch cer = 0.22857142857142856 train batch cer =  0.3
#  30%|██▉       | 4000/13426 [16:42<1:40:08,  1.57it/s]
# val batch cer = 0.2 train batch cer =  0.26666666666666666
#  37%|███▋      | 5000/13426 [20:51<1:38:51,  1.42it/s]
# val batch cer = 0.2571428571428571 train batch cer =  0
Cer: 0.0000
# 100%|██████████| 1492/1492 [06:25<00:00,  3.87it/s]
# test Loss: 0.3624 Cer: 0.0653
# ['Neapolitan', 'No5%', "industry's", 'in.']
# ['Neapolitan', '25%', "industry's", 'III.']

# %% [markdown]
# ### Only our data

# %%
df_train.head()
# Out:
#                                                  image      label
# 94726    data/data_words/r06/r06-007/r06-007-00-09.png          ,
# 28949    data/data_words/d01/d01-104/d01-104-01-07.png          ,
# 87379    data/data_words/n04/n04-171/n04-171-06-05.png  newspaper
# 7799            data/train_recognition/images/7799.png          1
# 51225  data/data_words/g06/g06-018j/g06-018j-08-01.png         of

# %%
df_train = df_train[['data_words' not in el for el in df_train['image']]]

# %%
from transformers import TrOCRProcessor

train_dataset = IAMDataset(root_dir='./',
                           df=df_train,
                           transforms=data_transforms['train'],
                           tokenizer=tokenizer,
                           feature_extractor=feature_extractor)

val_dataset = IAMDataset(root_dir='./',
                         df=df_val,
                         transforms=data_transforms['val'],
                         tokenizer=tokenizer,
                         feature_extractor=feature_extractor)

# %%
from torch.utils.data import DataLoader
batch_size = 8
train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True, num_workers=16,)
val_loader = DataLoader(val_dataset, batch_size=batch_size, shuffle=False, num_workers=16,)

# %%
model_type = 'eng_no_iam'

# %%
from torch.optim import lr_scheduler
optimizer = optim.Adam(model.parameters(), lr=5e-5)
lr_scheduler = None

# %%
loss_history, cer_history = train_model(model, train_loader, val_loader, lr_scheduler, optimizer, None, 8)
# Out:
# Epoch 0/7
# ----------
#  39%|███▉      | 1000/2571 [04:20<18:12,  1.44it/s]
# val batch cer = 0.9428571428571428 train batch cer =  0.9333333333333333
#  78%|███████▊  | 2000/2571 [08:29<06:18,  1.51it/s]
# val batch cer = 0.8857142857142857 train batch cer =  0.8333333333333334
# 100%|██████████| 2571/2571 [10:51<00:00,  3.94it/s]
# train Loss: 1.7102 Cer: 0.0000
# 100%|██████████| 1492/1492 [06:20<00:00,  3.92it/s]
# test Loss: 1.3092 Cer: 0.5011
# ['restrictions.', 'person', 'metals.', 'of']
# ['Neapolitan', '25%', "industry's", 'III.']
#
# updated best loss on 0 epoch, now it 1.3092066344003574
# Epoch 1/7
# ----------
#  39%|███▉      | 1000/2571 [04:15<19:56,  1.31it/s]
# val batch cer = 0.8285714285714286 train batch cer =  0.6333333333333333
#  78%|███████▊  | 2000/2571 [08:23<06:02,  1.57it/s]
# val batch cer = 0.8285714285714286 train batch cer =  0.5333333333333333
# 100%|██████████| 2571/2571 [10:45<00:00,  3.98it/s]
# train Loss: 0.4288 Cer: 0.0000
# 100%|██████████| 1492/1492 [06:32<00:00,  3.81it/s]
# test Loss: 0.9892 Cer: 0.3648
# ['women', 'some', "men's:", 'III.']
# ['Neapolitan', '25%', "industry's", 'III.']
#
# updated best loss on 1 epoch, now it 0.9891594008395284
# Epoch 2/7
# ----------
#  39%|███▉      | 1000/2571 [04:15<18:42,  1.40it/s]
# val batch cer = 0.6 train batch cer =  0.3333333333333333
#  78%|███████▊  | 2000/2571 [08:23<06:02,  1.57it/s]
# val batch cer = 0.8285714285714286 train batch cer =  0.4666666666666667
# 100%|██████████| 2571/2571 [10:45<00:00,  3.98it/s]
# train Loss: 0.2912 Cer: 0.0000
# 100%|██████████| 1492/1492 [06:31<00:00,  3.81it/s]
# test Loss: 0.9135 Cer: 0.3500
# ['improve.', 'asore', '"metal"', 'in.']
# ['Neapolitan', '25%', "industry's", 'III.']
#
# updated best loss on 2 epoch, now it 0.9135152001917641
# Epoch 3/7
# ----------
#  39%|███▉      | 1000/2571 [04:16<17:47,  1.47it/s]
# val batch cer = 0.8285714285714286 train batch cer =  0.4
#  78%|███████▊  | 2000/2571 [08:26<06:22,  1.49it/s]
# val batch cer = 0.7142857142857143 train batch cer =  0.36666666666666664
# 100%|██████████| 2571/2571 [10:48<00:00,  3.96it/s]
# train Loss: 0.2197 Cer: 0.0000
# 100%|██████████| 1492/1492 [06:35<00:00,  3.77it/s]
# test Loss: 1.2082 Cer: 0.3937
# ['-0%.', '536', ':-"', 'us.']
# ['Neapolitan', '25%', "industry's", 'III.']
#
# Epoch 4/7
# ----------
#  39%|███▉      | 1000/2571 [04:16<18:06,  1.45it/s]
# val batch cer = 0.8 train batch cer =  0.5666666666666667
#  78%|███████▊  | 2000/2571 [08:26<06:10,  1.54it/s]
# val batch cer = 0.8 train batch cer =  0.3
# 100%|██████████| 2571/2571 [10:48<00:00,  3.96it/s]
# train Loss: 0.1891 Cer: 0.0000
# 100%|██████████| 1492/1492 [06:37<00:00,  3.75it/s]
# test Loss: 1.1048 Cer: 0.3507
# ['comparison', 'vision', 'authors"', 'III.']
# ['Neapolitan', '25%', "industry's", 'III.']
#
# Epoch 5/7
# ----------
#  39%|███▉      | 1000/2571 [04:16<17:21,  1.51it/s]
# val batch cer = 0.7714285714285715 train batch cer =  0.4
#  78%|███████▊  | 2000/2571 [08:27<06:17,  1.51it/s]
# val batch cer = 0.8 train batch cer =  0.6333333333333333
# 100%|██████████| 2571/2571 [10:49<00:00,  3.96it/s]
# train Loss: 0.1610 Cer: 0.0000
# 100%|██████████| 1492/1492 [06:42<00:00,  3.71it/s]
# test Loss: 1.1914 Cer: 0.3714
# ['creative', 'asco', "master'", 'us.']
# ['Neapolitan', '25%', "industry's", 'III.']
#
# Epoch 6/7
# ----------
#  39%|███▉      | 1000/2571 [04:17<17:04,  1.53it/s]
# val batch cer = 0.9142857142857143 train batch cer =  0.5666666666666667
#  78%|███████▊  | 2000/2571 [08:29<06:19,  1.51it/s]
# val batch cer = 0.7428571428571429 train batch cer =  0.5333333333333333
# 100%|██████████| 2571/2571 [10:51<00:00,  3.95it/s]
# train Loss: 0.1388 Cer: 0.0000
# 100%|██████████| 1492/1492 [06:45<00:00,  3.68it/s]
# test Loss: 1.2223 Cer: 0.3634
# ['vezier-', '???', '"5"', 'in']
# ['Neapolitan', '25%', "industry's", 'III.']
#
# Epoch 7/7
# ----------
#  39%|███▉      | 1000/2571 [04:18<17:10,  1.52it/s]
# val batch cer = 0.8285714285714286 train batch cer =  0.6
#  78%|███████▊  | 2000/2571 [08:30<05:59,  1.59it/s]
# val batch cer = 0.8857142857142857 train batch cer =  0.7666666666666667
# 100%|██████████| 2571/2571 [10:52<00:00,  3.94it/s]
# train Loss: 0.1215 Cer: 0.0000
# 100%|██████████| 1492/1492 [06:49<00:00,  3.64it/s]
# test Loss: 1.8818 Cer: 0.4089
# ['imagine', 'is on', 'number.', 'N2']
# ['Neapolitan', '25%', "industry's", 'III.']

# %%
optimizer = optim.Adam(model.parameters(), lr=2e-5)
loss_history, cer_history = train_model(model, train_loader, val_loader, lr_scheduler, optimizer, None, 2)
# Out:
# Epoch 0/1
# ----------
#  39%|███▉      | 1000/2571 [04:15<17:12,  1.52it/s]
# val batch cer = 0.7142857142857143 train batch cer =  0.43333333333333335
#  78%|███████▊  | 2000/2571 [08:25<06:07,  1.55it/s]
# val batch cer = 0.7714285714285715 train batch cer =  0.36666666666666664
#  90%|█████████ | 2322/2571 [09:45<01:00,  4.09it/s]
